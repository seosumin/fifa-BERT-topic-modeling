# %% [markdown]
# # 1. 패키지 호출 및 FIFA_BERTopic 실행

# %%
from bertopic import BERTopic
import pickle as pkl

# %%
model = BERTopic(embedding_model="./random_all_epoch_2", verbose=True, nr_topics=10)

# %% [markdown]
# # 2. 데이터 호출 및 입력 형태 변환

# %%
# 기본 저장 주소
ROOT_PATH ="./Topic_Modeling/"
# 데이터 저장 주소
DATA_FOLDER_PATH = os.path.join(ROOT_PATH,"1.Data/")

# %%
with open(DATA_FOLDER_PATH +'fifa_data.pkl', 'rb') as f:
    train_ids=pkl.load(f)
    att_masks=pkl.load(f)
    df_fifa=pkl.load(f)
    token_pre=pkl.load(f)

# %%
join_text=[]
for token in token_pre:
    tmp=" ".join(token)
    join_text.append(tmp)

# %%
join_text
# Out:
# ['5백 2볼란치 비매너 친선 채팅 이야기 해당 경기 내용 포메이션',
#  '패키지 추천 9000 로추 풍년 토끼 3개추석 연쇄 패키지 구매',
#  '20 메시 로패 오버 메시 은카 로스터패치 오버',
#  '알파 19시즌 잉글랜드 풀백 금카 알파 가능',
#  '로랑 코시엘니 은카',
#  '컨뽕 컨뽕',
#  '겜 렉 2판 정도 3판 이적 시장 공경 할때 렉이 진짜 칠정 게임 문제 컴터 문제 컴터 사양 발로 란트 피파 화질 렉 답글 부탁',
#  '볼타 매칭 혹시 피파 관계자분들 게시판 모니터링 매칭시스템 개선 고객센터 문의 답변 모드 시작',
#  '요한 크루이프 1카 이거 고민입니다',
#  '이번 패키지 창렬 가격 형성 노랑 비교했을때 3배 벌써 하한 매물 보통 몇배',
#  '이번 시즌 급여 대부분 스쿼드 운영 굴리트 26날두 25지단 25레이카르트 24제라드 24말디니 24저급여 수미 저급여 풀백 저급여 어디 급여 건지 기존 시즌 고강 급여 패치 이상 시간 지나 기존카드 고강 역주행',
#  '블랑 잠브로 4카 보유 판매 블랑4카 현재 시세 잠브로 4카 현재 시세',
#  '첼시챔스우승 쓰리 3패치필요 패치3가지제안 전개속도50 90실축비주류포지션 포메이션 하향 실축존재 크로스중거리헤딩상향 키보드패드분리매칭 키보드자동수비상향 개인기대폭축소 매출상승가능성',
#  '이번 브라질 국대 수정 사항 이번 시즌 가격',
#  '최종 예선 본선 전초전 대표팀스쿼드 주소 인원 추가 인원 믿음 플레이 연결 디테일 약속 믿음 플레이 방식 이게 부류 축구 원팀 대표팀코치 스탭 선수',
#  '이번패치 초대박 피파 이유 피파 인사',
#  '닉네임 가치 얼마 정도 축구 게임 최적 닉네임 나름 자부심 가치 얼마 정도',
#  '피파 정기점검 문제점 피파 정기점검 문제점 개선',
#  '잼민이들 게시판 메인 댓글 개극혐',
#  '감독모드 1판 40분 12시 20분 정각 감독모드 돌리고 샤워 확인 시작 오프닝 유저 접속 시간 꼼수 부려 이건 에바',
# ...

# %% [markdown]
# # 3. 토픽 모델링 수행

# %%
topics, probabilities = model.fit_transform(join_text)
# Out:
# WARNING:root:No sentence-transformers model found with name ./fifa_bert/random_all_epoch_2. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at ./fifa_bert/random_all_epoch_2 were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1   8346
# 1       0   1185
# 2       1   1174
# 3       2   1124
# 4       3   1081
# 5       4    855
# 6       5    826
# 7       6    803
# 8       7    694
# 9       8    576
# 10      9    568

# %%
len(topics)
# Out:
# 17232

# %%
for i in range(0,10):
    for j in range(0, 10):
        print(model.get_topic(i)[j][0])
    print("")
# Out:
# 게임
# 이벤트
# 넥슨
# 문제
# 피파
# 개선
# 축구
# 때문
# 시간
# 플레이
#
# 키퍼
# 포인트
# 20
# 레벨
# 레벨업
# 골키퍼
# 보상
# 최근
# 스트레스
# 사용
#
# 쿠폰
# 키보드
# 박정무
# 2차쿠폰
# 패스
# 1차쿠폰
# 2차
# 1차
# 피파4불매운동
# 수비수
#
# 금카
# 스쿼드
# 7카
# 레알
# 밀란
# 가요
# 주세요
# 레알마드리드
# 추천
# 마드리드
#
# 강화
# 보정
# 조작
# 몰수패
# 패드립
# 넥슨
# 오류
# 보정이
# 풀게이지
# 이게
#
# 아이콘
# 구단가치
# 시간
# 넥슨
# 넥슨님
# 게임
# 이게
# 가격
# 피파
# 시대
#
# 20토티
# 21토티
# 노미니
# 가격
# 10억
# 5억
# 100억
# 1억
# 아이폰
# 30억
#
# 피파4
# 피파온라인4
# 키보드패드분리매칭
# 키보드자동수비상향
# 개인기대폭축소
# 크로스중거리헤딩상향
# 실축존재
# 90실축비주류포지션
# 연장점검
# 피파온라인
#
# 크로스
# 패스
# 터치
# 골대
# 순비피
# 크로스충
# 헤딩
# 박제
# 대한민국
# 포메이션
#
# 넥슨
# 유저
# 가격
# 불매운동
# 문제
# 피파
# 박정무
# 개돼지
# 기업
# 때문

# %% [markdown]
# ## 토픽 시각화

# %%
model.visualize_topics()
# Out:
# <div>                            <div id="c586a6d9-58c8-4dba-a7b9-35f4adb60306" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c586a6d9-58c8-4dba-a7b9-35f4adb60306")) {                    Plotly.newPlot(                        "c586a6d9-58c8-4dba-a7b9-35f4adb60306",                        [{"customdata": [[12.515453338623047, 16.1712589263916, 0, "\uac8c\uc784 | \uc774\ubca4\ud2b8 | \ub125\uc2a8 | \ubb38\uc81c | \ud53c\ud30c", 1185], [10.535919189453125, 11.994928359985352, 1, "\ud0a4\ud37c | \ud3ec\uc778\ud2b8 | 20 | \ub808\ubca8 | \ub808\ubca8\uc5c5", 1174], [11.809643745422363, 13.690156936645508, 2, "\ucfe0\ud3f0 | \ud0a4\ubcf4\ub4dc | \ubc15\uc815\ubb34 | 2\ucc28\ucfe0\ud3f0 | \ud328\uc2a4", 1124], [10.067459106445312, 11.460083961486816, 3, 
# ...

# %%
model.visualize_hierarchy()
# Out:
# <div>                            <div id="33e23332-c803-4b28-9785-61212309a341" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33e23332-c803-4b28-9785-61212309a341")) {                    Plotly.newPlot(                        "33e23332-c803-4b28-9785-61212309a341",                        [{"hoverinfo": "text", "marker": {"color": "rgb(61,153,112)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.10425291742804385, 0.10425291742804385, 0.0], "xaxis": "x", "y": [-45.0, -45.0, -55.0, -55.0], "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "rgb(61,153,112)"}, "mode": "lines", "type": "scatter", "x": [0.0, 0.11666785130923107, 0.11666785130923107, 0.10425291742804385], "xaxis": "x", "y": [-35.0, -35.0, -50.0, -50.0], "yaxis": "y"}, {"hover
# ...

# %%
model.visualize_barchart()
# Out:
# <div>                            <div id="f8517860-c955-4ac8-b8aa-38df4683690a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8517860-c955-4ac8-b8aa-38df4683690a")) {                    Plotly.newPlot(                        "f8517860-c955-4ac8-b8aa-38df4683690a",                        [{"orientation": "h", "type": "bar", "x": [0.022367171507685062, 0.022443969866377284, 0.02504883770178282, 0.026639818949228924, 0.032377197079832075], "xaxis": "x", "y": ["\ud53c\ud30c  ", "\ubb38\uc81c  ", "\ub125\uc2a8  ", "\uc774\ubca4\ud2b8  ", "\uac8c\uc784  "], "yaxis": "y"}, {"orientation": "h", "type": "bar", "x": [0.03104052761458172, 0.03157789851521978, 0.03157932858218675, 0.03709312806031672, 0.03794908865107455], "xaxis": "x2", "y": ["\ub808\ubca8
# ...

# %% [markdown]
# # 4. 이슈 트래킹 실행

# %%
timestamps=list(df_fifa['day'])

# %%
len(timestamps)
# Out:
# 17232

# %%
len(join_text)
# Out:
# 17232

# %%
topics, probs = model.fit_transform(join_text)
# Out:
# WARNING:root:No sentence-transformers model found with name ./fifa_bert/random_all_epoch_2. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at ./fifa_bert/random_all_epoch_2 were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
topics_over_time = model.topics_over_time(join_text, topics, timestamps, nr_bins=20)
# Out:
# 20it [00:25,  1.30s/it]

# %%
model.visualize_topics_over_time(topics_over_time, top_n_topics=10)
# Out:
# <div>                            <div id="7ca74aa7-cb8a-4b86-b808-d6598207a5be" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ca74aa7-cb8a-4b86-b808-d6598207a5be")) {                    Plotly.newPlot(                        "7ca74aa7-cb8a-4b86-b808-d6598207a5be",                        [{"hoverinfo": "text", "hovertext": ["<b>Topic 0</b><br>Words: \uba85\uc758\ub3c4\uc6a9\ud0c8\ud1f4, \uc774\ubca4\ud2b8, \ud504\ub85c, \uc774\ub780, \uc544\uc2dc\uc544", "<b>Topic 0</b><br>Words: \uc6d4\ud074, \uc774\ubca4\ud2b8, \ud53c\ud30c, \ub4dc\ub9bd\ub2c8\ub2e4, \ud655\uc9c4\uc790", "<b>Topic 0</b><br>Words: \ub85c\uc2a4\ud130\ud328\uce58, \ubaa8\ub4dc, \ubcf4\uc815, \uac8c\uc784, \uc774\ubca4\ud2b8", "<b>Topic 0</b><br>Words: \ub125\uc2a8, \uac8c\uc784, 
# ...
